# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import torch

check = torch.load('nonsaturating-gan.model')

# %%
plt.figure(figsize=(10,10))
plt.plot(check['g_losses'],'r')
plt.plot(check['d_losses'],'b')
